# %% [markdown]
# Analyse de l’impact du changement climatique à travers les Open Datas

# %% [markdown]
# Phase 1 — Recherche et acquisition de données

# %% [markdown]
# Analyse et Exploration des jeux de données

# %%
# librairies necessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Analyse du dataset: Temperature change

temp_change = pd.read_csv('temperature_change.csv')
temp_change.head()
# Out:
#   Domain Code                      Domain         Area             Element  \
# 0          ET  Temperature change on land  Afghanistan  Temperature change
# 1          ET  Temperature change on land  Afghanistan  Temperature change
# 2          ET  Temperature change on land  Afghanistan  Temperature change
# 3          ET  Temperature change on land  Afghanistan  Temperature change
# 4          ET  Temperature change on land  Afghanistan  Temperature change
#
#     Months  Year Unit  Value Flag Flag Description
# 0  January  1961   °c  0.745    E  Estimated value
# 1  January  1962   °c  0.015    E  Estimated value
# 2  January  1963   °c  2.706    E  Estimated value
# 3  January  1964   °c -5.250    E  Estimated value
# 4  January  1965   °c  1.854    E  Estimated value

# %%
temp_change.isnull().sum()
# Out:
# Domain Code             0
# Domain                  0
# Area                    0
# Element                 0
# Months                  0
# Year                    0
# Unit                    0
# Value               10260
# Flag                    0
# Flag Description        0
# dtype: int64

# %%
# Suppression des lignes avec trop de valeurs manquantes
temp_change = temp_change.dropna(axis=0, subset="Value")
temp_change.isnull().sum()

# %%
# Analyse du dataset: Natural disasters
nat_disaster = pd.read_excel('natural_disasters.xlsx')
nat_disaster.head()
# Out:
#           DisNo. Classification Key Disaster Group Disaster Subgroup  \
# 0  1960-0001-BGD    nat-hyd-flo-flo        Natural      Hydrological
# 1  1960-0002-IRN    nat-geo-ear-gro        Natural       Geophysical
# 2  1960-0007-PER    nat-geo-ear-gro        Natural       Geophysical
# 3  1960-0010-MAR    nat-geo-ear-gro        Natural       Geophysical
# 4  1960-0012-PHL    nat-met-sto-tro        Natural    Meteorological
#
#   Disaster Type  Disaster Subtype  ISO                     Country  \
# 0         Flood   Flood (General)  BGD                  Bangladesh
# 1    Earthquake   Ground movement  IRN  Iran (Islamic Republic of)
# 2    Earthquake   Ground movement  PER                        Peru
# 3    Earthquake   Ground movement  MAR                     Morocco
# 4         Storm  Tropical cyclone  PHL                 Philippines
#
#                          Subregion    Region  Magnitude   Magnitude Scale  \
# 0                    Southern Asia      Asia        NaN               Km2
# 1                    Southern Asia      Asia        6.0  Moment Magnitude
# 2  Latin America and the Caribbean  Americas        7.8  Moment Magnitude
# 3                  Northern Africa    Africa        5.9  Moment Magnitude
# 4               South-eastern Asia      Asia        NaN               Kph
#
#    Start Year  Start Month  Total Deaths  No. Homeless  Total Affected  \
# 0        1960          NaN       10000.0           NaN             NaN
# 1        1960          4.0         480.0           NaN             NaN
# 2        1960          1.0          63.0           NaN           200.0
# 3        1960          2.0       13100.0           NaN             NaN
# 4        1960          4.0          56.0           NaN             NaN
#
#    Total Damage ('000 US$)       CPI
# 0                      NaN  9.706216
# 1                  20000.0  9.706216
# 2                      NaN  9.706216
# 3                 120000.0  9.706216
# 4                   2000.0  9.706216

# %%
nat_disaster.isnull().sum()

# %%
# Number of rows : 16061
# gestions des valeurs manquantes
nat_disaster['Magnitude'] = nat_disaster.groupby('Disaster Type')['Magnitude'].transform(lambda x: x.fillna(x.mean()))
nat_disaster['Total Affected'] = nat_disaster.groupby('Disaster Type')['Total Affected'].transform(lambda x: x.fillna(x.mean()))

# Suppression des lignes avec trop de valeurs manquantes
nat_disaster = nat_disaster.dropna(axis=0, subset="CPI")
nat_disaster = nat_disaster.dropna(axis=0, subset="Start Month")

nat_disaster.isnull().sum()
# Out:
# DisNo.                         0
# Classification Key             0
# Disaster Group                 0
# Disaster Subgroup              0
# Disaster Type                  0
# Disaster Subtype               0
# ISO                            0
# Country                        0
# Subregion                      0
# Region                         0
# Magnitude                   1075
# Magnitude Scale             1821
# Start Year                     0
# Start Month                    0
# Total Deaths                4285
# No. Homeless               13014
# Total Affected                 0
# Total Damage ('000 US$)    10138
# CPI                            0
# dtype: int64

# %% [markdown]
# Fusion des datasets

# %%
# Renommage des colonnes
nat_disaster.rename(columns={'Start Year': 'Year', 'Start Month': 'Month'}, inplace=True)

temp_change.rename(columns={'Area': 'Country'}, inplace=True)

print("Colonnes de temp_change :", temp_change.columns)
print("Colonnes de nat_disaster :", nat_disaster.columns)
# Out:
# Colonnes de temp_change : Index(['Domain Code', 'Domain', 'Country', 'Element', 'Months', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')
# Colonnes de nat_disaster : Index(['DisNo.', 'Classification Key', 'Disaster Group', 'Disaster Subgroup',
#        'Disaster Type', 'Disaster Subtype', 'ISO', 'Country', 'Subregion',
#        'Region', 'Magnitude', 'Magnitude Scale', 'Year', 'Month',
#        'Total Deaths', 'No. Homeless', 'Total Affected',
#        'Total Damage ('000 US$)', 'CPI'],
#       dtype='object')

# %%
# Merge des deux datasets
merged_data = pd.merge(temp_change, nat_disaster, on=['Country', 'Year'], how='inner')
merged_data.head()

merged_data = merged_data.to_csv('merged_data.csv', index=False)
